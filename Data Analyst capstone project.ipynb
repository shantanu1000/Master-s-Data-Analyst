# %%
import pandas as pd 
import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns

# %%
path = "D:/Shantanu/Simplilearn/Capstone project/1591617926_data/data.xlsx"
df = pd.read_excel(path)
df.head()
# Out:
#    Restaurant ID              Restaurant Name  Country Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9550 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Price range           9551 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         1
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df[df["Restaurant Name"].isnull()]
# Out:
#       Restaurant ID Restaurant Name  Country Code       City  \
# 1646         113702             NaN             1  Ahmedabad
#
#                                           Address  Locality  \
# 1646  Opposite Sindhu Bhawan, Bodakdev, Ahmedabad  Bodakdev
#
#          Locality Verbose  Longitude   Latitude  \
# 1646  Bodakdev, Ahmedabad  72.501764  23.040163
#
#                                          Cuisines  Average Cost for two  \
# 1646  North Indian, Continental, Mexican, Italian                   800
#
#                 Currency Has Table booking Has Online delivery  Price range  \
# 1646  Indian Rupees(Rs.)                No                  No            3
#
#       Aggregate rating Rating color Rating text  Votes
# 1646               4.1        Green   Very Good    769

# %%
df[df["Cuisines"].isnull()]
# Out:
#       Restaurant ID                 Restaurant Name  Country Code  \
# 9083       17374552                  Corkscrew Cafe           216
# 9086       17501439                        Dovetail           216
# 9094       17059060                       Hillstone           216
# 9406       17284158               Jimmie's Hot Dogs           216
# 9494       17142698                Leonard's Bakery           216
# 9504       17616465        Tybee Island Social Club           216
# 9533       17284105                   Cookie Shoppe           216
# 9535       17284211  Pearly's Famous Country Cookng           216
# 9539       17606621            HI Lite Bar & Lounge           216
#
#                 City                                          Address  \
# 9083     Gainesville                51 W Main St, Dahlonega, GA 30533
# 9086           Macon                   543 Cherry St, Macon, GA 31201
# 9094         Orlando  215 South Orlando Avenue, Winter Park, FL 32789
# ...

# %%
df.dropna(axis = 0, subset = ["Restaurant Name"], inplace = True)
df.reset_index(drop = True, inplace = True)

# %%
df["Cuisines"].fillna("Others", inplace = True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9550 entries, 0 to 9549
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         9550 non-null   int64
#  1   Restaurant_Name       9550 non-null   object
#  2   Country_Code          9550 non-null   int64
#  3   City                  9550 non-null   object
#  4   Address               9550 non-null   object
#  5   Locality              9550 non-null   object
#  6   Locality_Verbose      9550 non-null   object
#  7   Longitude             9550 non-null   float64
#  8   Latitude              9550 non-null   float64
#  9   Cuisines              9550 non-null   object
#  10  Average_Cost_for_two  9550 non-null   int64
#  11  Currency              9550 non-null   object
#  12  Has_Table_booking     9550 non-null   object
#  13  Has_Online_delivery   9550 non-null   object
#  14  Price_range           9550 non-null   int64
# ...

# %%
cc = pd.read_excel("D:/Shantanu/Simplilearn/Capstone project/1591617926_data/Country-Code.xlsx")
cc.columns = cc.columns.str.replace(" ", "_")

# %%
df_res = pd.merge(df, cc, on = "Country_Code", how = "outer")
df_res.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
df_cc = df_res.groupby(["Country_Code", "Country"]).agg( Count = ("Restaurant_ID", "count"))
df_cc.sort_values(by = "Count", ascending = False)
# Out:
#                              Count
# Country_Code Country
# 1            India            8651
# 216          United States     434
# 215          United Kingdom     80
# 30           Brazil             60
# 189          South Africa       60
# 214          UAE                60
# 148          New Zealand        40
# 208          Turkey             34
# 14           Australia          24
# 162          Phillipines        22
# 94           Indonesia          21
# 166          Qatar              20
# 184          Singapore          20
# 191          Sri Lanka          20
# 37           Canada              4

# %% [markdown]
# We observe that India has the highest number of Restaurants in the given data.
# United states has second highest number of restaurants in the data with Canada having the least amount of restaurants.

# %%
df_cc.plot(kind = "barh")
# Out:
# <AxesSubplot:ylabel='Country_Code,Country'>

# %%
df_city = df_res.groupby(["Country", "City"]).agg( Count = ("Restaurant_ID", "count"))
df_city.sort_values(by = "Count", ascending = False)
# Out:
#                               Count
# Country       City
# India         New Delhi        5473
#               Gurgaon          1118
#               Noida            1080
#               Faridabad         251
#               Ghaziabad          25
# ...                             ...
#               Panchkula           1
# Australia     Balingup            1
# Indonesia     Bandung             1
# Phillipines   Quezon City         1
# United States Winchester Bay      1
#
# [141 rows x 1 columns]

# %%
min_df_city = df_city[df_city["Count"]== 1]
min_df_city.info()

min_df_city
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 46 entries, ('Australia', 'Armidale') to ('United States', 'Winchester Bay')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Count   46 non-null     int64
# dtypes: int64(1)
# memory usage: 1.8+ KB
#                                 Count
# Country       City
# Australia     Armidale              1
#               Balingup              1
#               Beechworth            1
#               Dicky Beach           1
#               East Ballina          1
#               Flaxton               1
#               Forrest               1
#               Huskisson             1
#               Inverloch             1
#               Lakes Entrance        1
#               Lorn                  1
#               Macedon               1
#               Mayfield              1
#               Middleton Beach       1
#               Montville             1
# ...

# %% [markdown]
# New Delhi has the highest number of restaurants in the data and there are 46 cities in  countries with minimum number of restaurants in the data i.e = 1

# %%
df["Restaurant_Name"].describe()
# Out:
# count                9550
# unique               7445
# top       Cafe Coffee Day
# freq                   83
# Name: Restaurant_Name, dtype: object

# %%
df["Restaurant_Name"].value_counts()
# Out:
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Bitoo Chat Corner            1
# The Categorical Eat Pham     1
# Thalaivaa                    1
# Aap Ki Rasoi Ghar            1
# The Gem Bar & Restaurant     1
# Name: Restaurant_Name, Length: 7445, dtype: int64

# %%
df_fran = df_res.groupby(["Country", "Restaurant_Name"]).agg( Count = ("Restaurant_Name", "count"))
df_fran.sort_values(by = "Count", ascending = False)
# Out:
#                                 Count
# Country       Restaurant_Name
# India         Cafe Coffee Day      83
#               Domino's Pizza       79
#               Subway               63
#               Green Chick Chop     51
#               McDonald's           48
# ...                               ...
#               Hawai Adda            1
#               Havemore              1
#               Haveliram             1
#               Hauz Khas Social      1
# United States Zunzi's               1
#
# [7472 rows x 1 columns]

# %%
df_fran[df_fran["Count"] >= 10].sort_values(by = "Count", ascending = False)
# Out:
#                               Count
# Country Restaurant_Name
# India   Cafe Coffee Day          83
#         Domino's Pizza           79
#         Subway                   63
#         Green Chick Chop         51
#         McDonald's               48
#         Keventers                34
#         Pizza Hut                29
#         Giani                    29
#         Baskin Robbins           28
#         Barbeque Nation          25
#         Dunkin' Donuts           22
#         Giani's                  22
#         Barista                  22
#         Pind Balluchi            20
#         Costa Coffee             20
#         Pizza Hut Delivery       19
#         Wah Ji Wah               19
#         Twenty Four Seven        19
#         Sagar Ratna              19
#         KFC                      18
#         Chaayos                  18
#         Republic of Chicken      18
#         Starbucks                17
#         Haldiram's               16
# ...

# %%
df_fran.loc["United States"].sort_values(by = "Count", ascending = False)
# Out:
#                                Count
# Restaurant_Name
# Texas Roadhouse                    4
# HuHot Mongolian Grill              3
# Granite City Food & Brewery        2
# Chick-fil-A                        2
# Mellow Mushroom                    2
# ...                              ...
# Flying Pie Pizzaria                1
# Flying Mango                       1
# Flounders Chowder House            1
# Flatbread Neapolitan Pizzeria      1
# Zunzi's                            1
#
# [423 rows x 1 columns]

# %%
df_fran.loc["United Kingdom"].sort_values(by = "Count", ascending = False)
# Out:
#                      Count
# Restaurant_Name
# Jamie's Italian          3
# Chaophraya               3
# San Carlo                2
# Dishoom                  2
# Steak                    1
# ...                    ...
# Hard Rock Cafe           1
# Handmade Burger Co.      1
# Hakkasan                 1
# Gymkhana                 1
# sketch Gallery           1
#
# [74 rows x 1 columns]

# %%
df_fran_Ind = df_fran[df_fran["Count"] >= 20].sort_values(by = "Count", ascending = False)
df_fran_Ind.plot(kind = "barh")
# Out:
# <AxesSubplot:ylabel='Country,Restaurant_Name'>

# %%
## We can conclude that in India Franchises of Cafe Coffee Day, Domino's Pizza and Subway have the highest number of 
#outlets throughout the country respectively.
## The data of other countries is too small to calculate franchises of restaurants having nationwide presence.

# %%
df_Table = df_res.groupby(["Has_Table_booking"]).agg( Count = ("Restaurant_ID", "count"))
df_Table
# Out:
#                    Count
# Has_Table_booking
# No                  8392
# Yes                 1158

# %%
ratio = round(df_Table.loc["Yes"].sum()/df_Table.loc["No"].sum(), 2)
ratio
# Out:
# 0.14

# %%
labels = ["Yes","No"]

sizes = [1158,8392]

plt.pie(sizes, labels = labels, autopct = '%1.2f%%')

plt.axis("equal")
plt.show()

## We can observe that only 12.13% of Restaurants provide Table Booking and 87.87% dont.

# %%
df_online = df_res.groupby(["Has_Online_delivery"]).agg( Count = ("Restaurant_ID", "count"))
df_online
# Out:
#                      Count
# Has_Online_delivery
# No                    7099
# Yes                   2451

# %%
labels = ["Online Delivery","No Online Delivery"]

sizes = [2451,7099]

plt.pie(sizes, labels = labels, autopct = '%1.2f%%')

plt.axis("equal")
plt.show()

## We can see that 25.66% of restaurants have online delivery and 74.34% of restaurants dont have.

# %%
df_online_v = df_res.groupby(["Has_Online_delivery"])["Votes"].sum()
df_online_v
# Out:
# Has_Online_delivery
# No     979962
# Yes    517914
# Name: Votes, dtype: int64

# %%
Difference = round(df_online_v.loc["No"].sum() - df_online_v.loc["Yes"].sum(), 2)
Difference 

## There is a difference of 462048 votes between Restaurants that deliver food online and those that do not.
# Out:
# 462048

# %%
labels = ["Votes for restaurants with Online Delivery","Votes for restaurants with no online delivery"]

sizes = [517914,979962]

plt.pie(sizes, labels = labels, autopct = '%1.2f%%')

plt.axis("equal")
plt.show()

# %%
df_res["Cuisines"].unique()
# Out:
# array(['Italian, Continental', 'Asian, Indonesian, Western',
#        'Sushi, Japanese', ..., 'Coffee and Tea, Desserts, Beverages',
#        'Desserts, Pizza, Ice Cream', 'Chinese, Canadian'], dtype=object)

# %%
df_res["Cuisines"].value_counts()
# Out:
# North Indian                                            936
# North Indian, Chinese                                   511
# Chinese                                                 354
# Fast Food                                               354
# North Indian, Mughlai                                   334
#                                                        ...
# North Indian, Mughlai, Biryani, Bengali                   1
# Asian, Chinese, Thai, Malaysian, Indonesian, Burmese      1
# Bakery, Beverages, Fast Food                              1
# Continental, American, Cafe                               1
# American, Greek, Seafood                                  1
# Name: Cuisines, Length: 1826, dtype: int64

# %%
df_res['Cus_len'] = df_res['Cuisines'].apply(lambda n: len(n.split(",")))
df_res[["Cuisines", "Cus_len"]]
# Out:
#                            Cuisines  Cus_len
# 0              Italian, Continental        2
# 1        Asian, Indonesian, Western        3
# 2                   Sushi, Japanese        2
# 3                          Japanese        1
# 4                   French, Western        2
# ...                             ...      ...
# 9545                        Mexican        1
# 9546  Italian, Mediterranean, Pizza        3
# 9547                Japanese, Sushi        2
# 9548              Chinese, Canadian        2
# 9549                          Asian        1
#
# [9550 rows x 2 columns]

# %%
cuisines = df_res['Cuisines'].apply(lambda x: pd.Series(x.split(',')))
cuisines
# Out:
#              0               1         2    3    4    5    6    7
# 0      Italian     Continental       NaN  NaN  NaN  NaN  NaN  NaN
# 1        Asian      Indonesian   Western  NaN  NaN  NaN  NaN  NaN
# 2        Sushi        Japanese       NaN  NaN  NaN  NaN  NaN  NaN
# 3     Japanese             NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 4       French         Western       NaN  NaN  NaN  NaN  NaN  NaN
# ...        ...             ...       ...  ...  ...  ...  ...  ...
# 9545   Mexican             NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 9546   Italian   Mediterranean     Pizza  NaN  NaN  NaN  NaN  NaN
# 9547  Japanese           Sushi       NaN  NaN  NaN  NaN  NaN  NaN
# 9548   Chinese        Canadian       NaN  NaN  NaN  NaN  NaN  NaN
# 9549     Asian             NaN       NaN  NaN  NaN  NaN  NaN  NaN
#
# [9550 rows x 8 columns]

# %%
cuisines.columns = ['Cuisine_1','Cuisine_2','Cuisine_3','Cuisine_4','Cuisine_5','Cuisine_6','Cuisine_7','Cuisine_8']
cuisines.tail()
# Out:
#      Cuisine_1       Cuisine_2 Cuisine_3 Cuisine_4 Cuisine_5 Cuisine_6  \
# 9545   Mexican             NaN       NaN       NaN       NaN       NaN
# 9546   Italian   Mediterranean     Pizza       NaN       NaN       NaN
# 9547  Japanese           Sushi       NaN       NaN       NaN       NaN
# 9548   Chinese        Canadian       NaN       NaN       NaN       NaN
# 9549     Asian             NaN       NaN       NaN       NaN       NaN
#
#      Cuisine_7 Cuisine_8
# 9545       NaN       NaN
# 9546       NaN       NaN
# 9547       NaN       NaN
# 9548       NaN       NaN
# 9549       NaN       NaN

# %%
cuisines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9550 entries, 0 to 9549
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Cuisine_1  9550 non-null   object
#  1   Cuisine_2  6147 non-null   object
#  2   Cuisine_3  2703 non-null   object
#  3   Cuisine_4  863 non-null    object
#  4   Cuisine_5  280 non-null    object
#  5   Cuisine_6  116 non-null    object
#  6   Cuisine_7  42 non-null     object
#  7   Cuisine_8  14 non-null     object
# dtypes: object(8)
# memory usage: 929.5+ KB

# %%
cuisines.describe()
# Out:
#            Cuisine_1 Cuisine_2 Cuisine_3 Cuisine_4 Cuisine_5 Cuisine_6  \
# count           9550      6147      2703       863       280       116
# unique           120       116        99        72        50        36
# top     North Indian   Chinese   Chinese   Italian   Chinese    Mithai
# freq            2991      1156       594        84        41        23
#
#         Cuisine_7 Cuisine_8
# count          42        14
# unique         16         5
# top      Desserts    Mithai
# freq           24         8

# %%
df_cui_res = pd.concat([df_res, cuisines], axis = 1)
df_cui_res.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
cuisine_loc = pd.DataFrame (df_cui_res[['Country', 'City', 'Locality_Verbose', 'Cuisine_1','Cuisine_2','Cuisine_3','Cuisine_4','Cuisine_5','Cuisine_6','Cuisine_7','Cuisine_8']])
cuisine_loc
# Out:
#             Country              City                        Locality_Verbose  \
# 0         Indonesia           Jakarta  Grand Indonesia Mall, Thamrin, Jakarta
# 1         Indonesia           Jakarta     Hotel Shangri-La, Sudirman, Jakarta
# 2         Indonesia           Jakarta                    Penjaringan, Jakarta
# 3         Indonesia           Jakarta                       Senopati, Jakarta
# 4         Indonesia           Jakarta                        Thamrin, Jakarta
# ...             ...               ...                                     ...
# 9545  United States         Pocatello                    Pocatello, Pocatello
# 9546         Canada  Vineland Station      Vineland Station, Vineland Station
# 9547         Canada      Chatham-Kent              Chatham-Kent, Chatham-Kent
# 9548         Canada           Consort                        Consort, Consort
# 9549         Canada           Yorkton                        Yorkton, Yorkton
#
# ...

# %%
cuisine_loc_stack = pd.DataFrame(cuisine_loc.stack())
cuisine_loc_stack
# Out:
#                                                             0
# 0    Country                                        Indonesia
#      City                                             Jakarta
#      Locality_Verbose  Grand Indonesia Mall, Thamrin, Jakarta
#      Cuisine_1                                        Italian
#      Cuisine_2                                    Continental
# ...                                                       ...
# 9548 Cuisine_2                                       Canadian
# 9549 Country                                           Canada
#      City                                             Yorkton
#      Locality_Verbose                        Yorkton, Yorkton
#      Cuisine_1                                          Asian
#
# [48365 rows x 1 columns]

# %%
keys = [c for c in cuisine_loc  if c.startswith('Cuisine')]
a=pd.melt(cuisine_loc, id_vars='City', value_vars=keys, value_name='Cuisines')
a
# Out:
#                    City   variable  Cuisines
# 0               Jakarta  Cuisine_1   Italian
# 1               Jakarta  Cuisine_1     Asian
# 2               Jakarta  Cuisine_1     Sushi
# 3               Jakarta  Cuisine_1  Japanese
# 4               Jakarta  Cuisine_1    French
# ...                 ...        ...       ...
# 76395         Pocatello  Cuisine_8       NaN
# 76396  Vineland Station  Cuisine_8       NaN
# 76397      Chatham-Kent  Cuisine_8       NaN
# 76398           Consort  Cuisine_8       NaN
# 76399           Yorkton  Cuisine_8       NaN
#
# [76400 rows x 3 columns]

# %%
a.dropna()
# Out:
#                City   variable        Cuisines
# 0           Jakarta  Cuisine_1         Italian
# 1           Jakarta  Cuisine_1           Asian
# 2           Jakarta  Cuisine_1           Sushi
# 3           Jakarta  Cuisine_1        Japanese
# 4           Jakarta  Cuisine_1          French
# ...             ...        ...             ...
# 70252         Noida  Cuisine_8          Mithai
# 71231     New Delhi  Cuisine_8          Mithai
# 71964     New Delhi  Cuisine_8       Beverages
# 75566  Johannesburg  Cuisine_8   International
# 75574      Pretoria  Cuisine_8   International
#
# [19715 rows x 3 columns]

# %%
top_res = pd.DataFrame(a.groupby(['City', 'Cuisines']).size().reset_index())
top_res
# Out:
#            City         Cuisines  0
# 0     Abu Dhabi          Afghani  1
# 1     Abu Dhabi          Arabian  2
# 2     Abu Dhabi            Asian  1
# 3     Abu Dhabi          Biryani  1
# 4     Abu Dhabi           Burger  1
# ...         ...              ... ..
# 2402  €¡stanbul         Desserts  2
# 2403  €¡stanbul          Italian  1
# 2404  €¡stanbul  Restaurant Cafe  4
# 2405  €¡stanbul          Turkish  1
# 2406  €¡stanbul    World Cuisine  1
#
# [2407 rows x 3 columns]

# %%
top_res.columns = ["City", "Cuisines", "Count"]  

top_res['Cuisines'].unique()
# Out:
# array([' Afghani', ' Arabian', ' Asian', ' Biryani', ' Burger',
#        ' Chinese', ' Desserts', ' Hyderabadi', ' Indian', ' Indonesian',
#        ' Japanese', ' Mexican', ' Middle Eastern', ' Mughlai',
#        ' North Indian', ' Pizza', ' Seafood', ' South Indian',
#        ' Vietnamese', 'American', 'Asian', 'Chinese', 'Fast Food',
#        'Filipino', 'Indian', 'Italian', 'Lebanese', 'Pakistani', 'Thai',
#        'Turkish', ' Continental', ' European', ' Fast Food', ' Gujarati',
#        ' Italian', 'Cafe', 'Mughlai', 'North Indian', 'Rajasthani',
#        'South Indian', ' American', ' Armenian', ' Beverages', ' Cafe',
#        ' Healthy Food', ' Ice Cream', ' Mediterranean', ' Sandwich',
#        ' Street Food', ' Thai', 'Continental', 'Desserts', 'Ice Cream',
#        'Pizza', ' BBQ', ' Bar Food', ' Breakfast', ' Diner', ' Steak',
#        ' Sushi', ' Tapas', ' Vegetarian', 'BBQ', 'Coffee and Tea',
#        'Japanese', 'Mexican', 'Others', 'Seafood', 'Steak', ' Salad',
# ...

# %%
top_res['Cuisines'] = top_res['Cuisines'].str.lstrip()
top_res['Cuisines'].unique()
# Out:
# array(['Afghani', 'Arabian', 'Asian', 'Biryani', 'Burger', 'Chinese',
#        'Desserts', 'Hyderabadi', 'Indian', 'Indonesian', 'Japanese',
#        'Mexican', 'Middle Eastern', 'Mughlai', 'North Indian', 'Pizza',
#        'Seafood', 'South Indian', 'Vietnamese', 'American', 'Fast Food',
#        'Filipino', 'Italian', 'Lebanese', 'Pakistani', 'Thai', 'Turkish',
#        'Continental', 'European', 'Gujarati', 'Cafe', 'Rajasthani',
#        'Armenian', 'Beverages', 'Healthy Food', 'Ice Cream',
#        'Mediterranean', 'Sandwich', 'Street Food', 'BBQ', 'Bar Food',
#        'Breakfast', 'Diner', 'Steak', 'Sushi', 'Tapas', 'Vegetarian',
#        'Coffee and Tea', 'Others', 'Salad', 'Bakery', 'Mithai', 'DÌ_ner',
#        'Izgara', 'Turkish Pizza', 'Kebab', 'Patisserie', 'World Cuisine',
#        'Argentine', 'Korean', 'Latin American', 'Southern',
#        'Southwestern', 'Spanish', 'International', 'Fusion', 'Kiwi',
# ...

# %%
loc = top_res.sort_values('Count', ascending=False).groupby(by = "City").first()
loc.head()
# Out:
#                Cuisines  Count
# City
# Abu Dhabi        Indian      6
# Agra       North Indian     12
# Ahmedabad   Continental      8
# Albany         American      4
# Allahabad  North Indian     10

# %%
City_loc = loc.sort_values(by = "Count", ascending = False).groupby(['City', 'Cuisines']).first()
City_loc1 = City_loc[City_loc["Count"] > 5].sort_values(by = "Count", ascending = False)
City_loc1
# Out:
#                                      Count
# City                   Cuisines
# New Delhi              North Indian   1848
# Noida                  North Indian    433
# Gurgaon                North Indian    367
# Faridabad              North Indian    102
# Amritsar               North Indian     15
# Ranchi                 Chinese          13
# Agra                   North Indian     12
# Patna                  Chinese          12
# Allahabad              North Indian     10
# Ankara                 Kebab            10
# Nashik                 North Indian     10
# Rio de Janeiro         Brazilian        10
# Ludhiana               Chinese          10
# Dehradun               Chinese           9
# Ghaziabad              North Indian      9
# Dubuque                American          9
# Jaipur                 Continental       9
# Chennai                North Indian      9
# Indore                 North Indian      9
# Mysore                 North Indian      9
# ...

# %% [markdown]
# We can see the diiferent Cuisines preferred across cities. North Indian is the most presferred cuisine across cities.

# %%
plt.rcParams["figure.figsize"] = (10,10)
City_loc1.plot(kind = "barh")
# Out:
# <AxesSubplot:ylabel='City,Cuisines'>

# %%
City_loc2 = loc.sort_values(by = "Count", ascending = False).groupby(['Cuisines', 'City']).first()
City_loc2
# Out:
#                                  Count
# Cuisines City
# American Albany                      4
#          Athens                      5
#          Boise                       8
#          Cedar Rapids/Iowa City      7
#          Clatskanie                  1
# ...                                ...
# Sushi    Macon                       4
# Tapas    Inner City                  1
# Tea      Flaxton                     1
# Thai     Lincoln                     1
# Western  Jakarta                     7
#
# [141 rows x 1 columns]

# %%
df_cui_res[df_cui_res["Cuisine_8"].notnull()]
# Out:
#       Restaurant_ID       Restaurant_Name  Country_Code          City  \
# 960        18318116               R' ADDA             1        Mumbai
# 1221       18463285           Mumbai Vibe             1        Mumbai
# 2736         313316           Bikanervala             1       Gurgaon
# 3224       18279982    Indian Summer Cafe             1         Patna
# 3310         305303           Bikanervala             1     New Delhi
# 3340            491           Bikanervala             1     New Delhi
# 3357            492           Bikanervala             1     New Delhi
# 3376            497           Bikanervala             1     New Delhi
# 3393       18446491           Bikanervala             1     New Delhi
# 3402         307566           Bikanervala             1         Noida
# 4381           4055           Bikanervala             1     New Delhi
# 5114       18381220  Healthy Food Station             1     New Delhi
# ...

# %% [markdown]
# The most number of cuisines provided by a restaurant is 8. The List of restaurants with maximum number of cuisines is given above.

# %%
#Finding the Distribution of cost across restaurants
##Since avg price for 2 is in different currencies, we will consider the price range column 
##with 1 being the cheapest and 5 being the costliest

# %%
df_cui_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9550 entries, 0 to 9549
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         9550 non-null   int64
#  1   Restaurant_Name       9550 non-null   object
#  2   Country_Code          9550 non-null   int64
#  3   City                  9550 non-null   object
#  4   Address               9550 non-null   object
#  5   Locality              9550 non-null   object
#  6   Locality_Verbose      9550 non-null   object
#  7   Longitude             9550 non-null   float64
#  8   Latitude              9550 non-null   float64
#  9   Cuisines              9550 non-null   object
#  10  Average_Cost_for_two  9550 non-null   int64
#  11  Currency              9550 non-null   object
#  12  Has_Table_booking     9550 non-null   object
#  13  Has_Online_delivery   9550 non-null   object
#  14  Price_range           9550 non-null   int64
# ...

# %%
Price_range_a = pd.DataFrame (df_cui_res[['Country', 'City', 'Locality_Verbose','Price_range', 'Cuisine_1','Cuisine_2','Cuisine_3','Cuisine_4','Cuisine_5','Cuisine_6','Cuisine_7','Cuisine_8']])
Price_range_a
# Out:
#             Country              City                        Locality_Verbose  \
# 0         Indonesia           Jakarta  Grand Indonesia Mall, Thamrin, Jakarta
# 1         Indonesia           Jakarta     Hotel Shangri-La, Sudirman, Jakarta
# 2         Indonesia           Jakarta                    Penjaringan, Jakarta
# 3         Indonesia           Jakarta                       Senopati, Jakarta
# 4         Indonesia           Jakarta                        Thamrin, Jakarta
# ...             ...               ...                                     ...
# 9545  United States         Pocatello                    Pocatello, Pocatello
# 9546         Canada  Vineland Station      Vineland Station, Vineland Station
# 9547         Canada      Chatham-Kent              Chatham-Kent, Chatham-Kent
# 9548         Canada           Consort                        Consort, Consort
# 9549         Canada           Yorkton                        Yorkton, Yorkton
#
# ...

# %%
Price_range_a['Cuisine_1'] = Price_range_a['Cuisine_1'].str.lstrip()
Price_range_a['Cuisine_2'] = Price_range_a['Cuisine_2'].str.lstrip()
Price_range_a['Cuisine_3'] = Price_range_a['Cuisine_3'].str.lstrip()
Price_range_a['Cuisine_4'] = Price_range_a['Cuisine_4'].str.lstrip()
Price_range_a['Cuisine_5'] = Price_range_a['Cuisine_5'].str.lstrip()
Price_range_a['Cuisine_6'] = Price_range_a['Cuisine_6'].str.lstrip()
Price_range_a['Cuisine_7'] = Price_range_a['Cuisine_7'].str.lstrip()
Price_range_a['Cuisine_8'] = Price_range_a['Cuisine_8'].str.lstrip()

# %%
pr_plot = Price_range_a.groupby(["Price_range"]).agg(Count = ("Price_range", "count"))
pr_plot
# Out:
#              Count
# Price_range
# 1             4444
# 2             3113
# 3             1407
# 4              586

# %%
pr_plot.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Price_range'>

# %%
keys = [c for c in Price_range_a  if c.startswith('Cuisine')]
pr_plot1 = pd.melt(Price_range_a, id_vars='Price_range', value_vars=keys, value_name='Cuisines')
pr_plot1
# Out:
#        Price_range   variable  Cuisines
# 0                3  Cuisine_1   Italian
# 1                3  Cuisine_1     Asian
# 2                3  Cuisine_1     Sushi
# 3                3  Cuisine_1  Japanese
# 4                3  Cuisine_1    French
# ...            ...        ...       ...
# 76395            1  Cuisine_8       NaN
# 76396            4  Cuisine_8       NaN
# 76397            2  Cuisine_8       NaN
# 76398            2  Cuisine_8       NaN
# 76399            2  Cuisine_8       NaN
#
# [76400 rows x 3 columns]

# %%
pr_plot1.dropna()
# Out:
#        Price_range   variable       Cuisines
# 0                3  Cuisine_1        Italian
# 1                3  Cuisine_1          Asian
# 2                3  Cuisine_1          Sushi
# 3                3  Cuisine_1       Japanese
# 4                3  Cuisine_1         French
# ...            ...        ...            ...
# 70252            2  Cuisine_8         Mithai
# 71231            1  Cuisine_8         Mithai
# 71964            1  Cuisine_8      Beverages
# 75566            4  Cuisine_8  International
# 75574            4  Cuisine_8  International
#
# [19715 rows x 3 columns]

# %%
del pr_plot1['variable']

# %%
pr_plot1 = pr_plot1.groupby(['Cuisines', 'Price_range']).agg(Count = ('Price_range', 'count'))
pr_plot1
# Out:
#                            Count
# Cuisines      Price_range
# Afghani       1                3
#               2                9
#               3                2
# African       3                5
#               4                3
# ...                          ...
# Vietnamese    4                5
# Western       3                9
#               4                1
# World Cuisine 3                2
#               4                2
#
# [415 rows x 1 columns]

# %%
pr_plot1 = pd.DataFrame(pr_plot1).reset_index()
pr_plot1
# Out:
#           Cuisines  Price_range  Count
# 0          Afghani            1      3
# 1          Afghani            2      9
# 2          Afghani            3      2
# 3          African            3      5
# 4          African            4      3
# ..             ...          ...    ...
# 410     Vietnamese            4      5
# 411        Western            3      9
# 412        Western            4      1
# 413  World Cuisine            3      2
# 414  World Cuisine            4      2
#
# [415 rows x 3 columns]

# %%
pr_plot1.sort_values(by = "Count", ascending = False).head(20)
# Out:
#          Cuisines  Price_range  Count
# 288  North Indian            1   1555
# 289  North Indian            2   1537
# 134     Fast Food            1   1181
# 99        Chinese            2   1118
# 98        Chinese            1   1012
# 135     Fast Food            2    716
# 290  North Indian            3    668
# 274       Mughlai            2    569
# 38         Bakery            1    507
# 100       Chinese            3    489
# 367   Street Food            1    470
# 120      Desserts            1    401
# 346  South Indian            1    368
# 109   Continental            3    354
# 83           Cafe            2    349
# 199       Italian            3    324
# 262        Mithai            1    320
# 198       Italian            2    261
# 309         Pizza            2    238
# 347  South Indian            2    228

# %%
pr_plot1.columns = ["Cuisines", "Price_range", "Count"]

# %%
Price_range_4 = pr_plot1[pr_plot1["Price_range"] == 4].sort_values(by = "Count", ascending = False).head(15)
Price_range_4
# Out:
#           Cuisines  Price_range  Count
# 291   North Indian            4    199
# 110    Continental            4    131
# 200        Italian            4    125
# 101        Chinese            4    116
# 133       European            4     71
# 8         American            4     59
# 339        Seafood            4     52
# 143    Finger Food            4     51
# 23           Asian            4     50
# 205       Japanese            4     40
# 394           Thai            4     38
# 276        Mughlai            4     33
# 252  Mediterranean            4     30
# 85            Cafe            4     26
# 366          Steak            4     21

# %%
Price_range_3 = pr_plot1[pr_plot1["Price_range"] == 3].sort_values(by = "Count", ascending = False).head(15)
Price_range_3
# Out:
#           Cuisines  Price_range  Count
# 290   North Indian            3    668
# 100        Chinese            3    489
# 109    Continental            3    354
# 199        Italian            3    324
# 275        Mughlai            3    167
# 84            Cafe            3    149
# 7         American            3    123
# 22           Asian            3    117
# 393           Thai            3    107
# 136      Fast Food            3     83
# 338        Seafood            3     83
# 204       Japanese            3     70
# 255        Mexican            3     69
# 251  Mediterranean            3     64
# 132       European            3     63

# %%
Price_range_2 = pr_plot1[pr_plot1["Price_range"] == 2].sort_values(by = "Count", ascending = False).head(15)
Price_range_2
# Out:
#          Cuisines  Price_range  Count
# 289  North Indian            2   1537
# 99        Chinese            2   1118
# 135     Fast Food            2    716
# 274       Mughlai            2    569
# 83           Cafe            2    349
# 198       Italian            2    261
# 309         Pizza            2    238
# 347  South Indian            2    228
# 108   Continental            2    207
# 39         Bakery            2    198
# 121      Desserts            2    194
# 6        American            2    180
# 75         Burger            2    139
# 174  Healthy Food            2    114
# 59        Biryani            2     85

# %%
Price_range_1 = pr_plot1[pr_plot1["Price_range"] == 1].sort_values(by = "Count", ascending = False).head(15)
Price_range_1
# Out:
#          Cuisines  Price_range  Count
# 288  North Indian            1   1555
# 134     Fast Food            1   1181
# 98        Chinese            1   1012
# 38         Bakery            1    507
# 367   Street Food            1    470
# 120      Desserts            1    401
# 346  South Indian            1    368
# 262        Mithai            1    320
# 273       Mughlai            1    226
# 180     Ice Cream            1    211
# 82           Cafe            1    179
# 51      Beverages            1    172
# 322     Raw Meats            1    109
# 58        Biryani            1     79
# 308         Pizza            1     68

# %% [markdown]
# For the highest price range i.e 4, the cuisines North Indian, Continental, Italian and Chinese top the list of cuisines.
# For the lowest price range i.e 1, the cuisines North Indian, Fast Food, Chinese and Bakery are the cusines to look at.

# %%
Rating_pl = df_cui_res.groupby(["Aggregate_rating"]).agg(Count = ('Aggregate_rating', 'count'))
Rating_pl
# Out:
#                   Count
# Aggregate_rating
# 0.0                2148
# 1.8                   1
# 1.9                   2
# 2.0                   7
# 2.1                  15
# 2.2                  27
# 2.3                  47
# 2.4                  87
# 2.5                 110
# 2.6                 191
# 2.7                 250
# 2.8                 315
# 2.9                 381
# 3.0                 468
# 3.1                 519
# 3.2                 522
# 3.3                 483
# 3.4                 498
# 3.5                 480
# 3.6                 458
# 3.7                 427
# 3.8                 400
# 3.9                 335
# 4.0                 266
# 4.1                 273
# 4.2                 221
# 4.3                 174
# 4.4                 144
# 4.5                  95
# 4.6                  78
# 4.7                  42
# 4.8                  25
# 4.9                  61

# %%
Rating_pl.plot(kind = "barh")
# Out:
# <AxesSubplot:ylabel='Aggregate_rating'>

# %%
# The distribution curve of aggregate ratings of restaurants is normal if we do not consider the high number of restaurants which have rating 0 
## or are not rated and mentioned as 0

# %%
Highest_rated = df_cui_res[df_cui_res["Aggregate_rating"] >= 4.5]
Highest_rated
# Out:
#       Restaurant_ID           Restaurant_Name  Country_Code            City  \
# 1           7410290  Satoo - Hotel Shangri-La            94         Jakarta
# 2           7420899                Sushi Masa            94         Jakarta
# 9           7422633          Talaga Sampireun            94         Jakarta
# 11          7422751                Union Deli            94         Jakarta
# 13          7417455          Talaga Sampireun            94         Jakarta
# ...             ...                       ...           ...             ...
# 9505       17145077               Star Noodle           216  Rest of Hawaii
# 9507       17145495             Marukame Udon           216  Rest of Hawaii
# 9509       17615924       Leopold's Ice Cream           216        Savannah
# 9523       17095098  Mazzaro's Italian Market           216       Tampa Bay
# 9524       17093600                  Taco Bus           216       Tampa Bay
#
# ...

# %%
Highest_rated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301 entries, 1 to 9524
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         301 non-null    int64
#  1   Restaurant_Name       301 non-null    object
#  2   Country_Code          301 non-null    int64
#  3   City                  301 non-null    object
#  4   Address               301 non-null    object
#  5   Locality              301 non-null    object
#  6   Locality_Verbose      301 non-null    object
#  7   Longitude             301 non-null    float64
#  8   Latitude              301 non-null    float64
#  9   Cuisines              301 non-null    object
#  10  Average_Cost_for_two  301 non-null    int64
#  11  Currency              301 non-null    object
#  12  Has_Table_booking     301 non-null    object
#  13  Has_Online_delivery   301 non-null    object
#  14  Price_range           301 non-null    int64
# ...

# %%
Highest_rated.groupby(["City", "Country"]).agg(Count = ("City", "count")).sort_values(by = 'Count', ascending = False).head(15)
# Out:
#                                Count
# City           Country
# New Delhi      India              28
# London         United Kingdom     15
# Gurgaon        India              12
# Rio de Janeiro Brazil             11
# Tampa Bay      United States      10
# Rest of Hawaii United States       9
# Auckland       New Zealand         9
# Orlando        United States       9
# Bangalore      India               9
# Dubai          UAE                 9
# Abu Dhabi      UAE                 7
# Jakarta        Indonesia           6
# Hyderabad      India               6
# Goa            India               6
# Chennai        India               6

# %%
#The most Highest rated restaurants are in New Delhi, London, Gurgaon and Rio De Janeiro respectively

# %%
df_cui_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9550 entries, 0 to 9549
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         9550 non-null   int64
#  1   Restaurant_Name       9550 non-null   object
#  2   Country_Code          9550 non-null   int64
#  3   City                  9550 non-null   object
#  4   Address               9550 non-null   object
#  5   Locality              9550 non-null   object
#  6   Locality_Verbose      9550 non-null   object
#  7   Longitude             9550 non-null   float64
#  8   Latitude              9550 non-null   float64
#  9   Cuisines              9550 non-null   object
#  10  Average_Cost_for_two  9550 non-null   int64
#  11  Currency              9550 non-null   object
#  12  Has_Table_booking     9550 non-null   object
#  13  Has_Online_delivery   9550 non-null   object
#  14  Price_range           9550 non-null   int64
# ...

# %%
df_cui_res.corr()
# Out:
#                       Restaurant_ID  Country_Code  Longitude  Latitude  \
# Restaurant_ID              1.000000      0.148447  -0.226073 -0.052111
# Country_Code               0.148447      1.000000  -0.698298  0.019784
# Longitude                 -0.226073     -0.698298   1.000000  0.043213
# Latitude                  -0.052111      0.019784   0.043213  1.000000
# Average_Cost_for_two      -0.001696      0.043224   0.045892 -0.111089
# Price_range               -0.134419      0.243393  -0.078974 -0.166668
# Aggregate_rating          -0.326144      0.282234  -0.116843  0.000541
# Votes                     -0.146895      0.154593  -0.085141 -0.022927
# Cus_len                   -0.074624      0.009035   0.014792 -0.028972
#
#                       Average_Cost_for_two  Price_range  Aggregate_rating  \
# Restaurant_ID                    -0.001696    -0.134419         -0.326144
# Country_Code                      0.043224     0.243393          0.282234
# ...

# %%
## The Variables affecting the ratings are Price_range, Votes and Cusine length respectively.
